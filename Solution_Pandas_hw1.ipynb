# %% [markdown]
# # Five useful things form the Kaggle Kernal
#
# . It is a open platform to get variety of data.
#
# . Prize motivation for users to work towards a topic.
#
# . It provides open discussion forum where users can post their quries and disscus about their favorite topics.
#
# . It has a tab Kernel, where the user can browse topics like logistic regrssion and find useful codes.
#
# . Kaglle has also an important tab which post hundreds of open jobs.
#
# . Kaggle has open courses on machine learning and data sceince, therefore, it is one of the best website for data    sceintists.

# %% [markdown]
# # Describe in 15 sentences what can be done in Pandas

# %% [markdown]
# - Pandas is a library commonly used in data science for efficient handling of data and its analysis.
# - It provides tools to read data from several file.formats.
# - It is also used for resahping and pivoting of data.
# - There are useful functions to perform several tasks e.g. column insertion and deletion.
# - It provides easy and faster way of data slicing.
# - It is also used for data alignment and integrated handling of missing data.
# - This library is highly optimized for performance.
# - Some of the tools includes date range functionality and frequency conversion.
# - Pandas are build upon/ on top of Numpy.
# - Data set merging and joining can be easily performed by Pandas.
# - Pin point information can be excessable from a large set of data.
# - Slicing of the data can be easily done on label-based.
# - It provides functions for data cleaning and filtration.
# - High dimensional data work can be done in lower dimensional data structure due to hierarchical axis indexing.
# - The name is derived from the term ' panel data', an econometrics term for data sets that includes observations over - multiple time periods for the same individuals.

# %% [markdown]
# # Basic Info

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/rakeshm/Downloads/movie_data.txt",
                 delimiter="\t", names = ['ID', 'title', 'year', 'rating', 'votes', 'duration', 'genres'])

# %%
#df['ID'] = df.index

#can also be done by this
df.set_index('ID',inplace=True)

# %%
df
#df.set_index('ID',inplace=True)
# Out:
#                                                        title  year  rating  \
# ID
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0109830                                Forrest Gump (1994)  1994     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980     8.8
# tt0372784                               Batman Begins (2005)  2005     8.3
# ...

# %%
#printing out first five 
df.head()
# Out:
#                                      title  year  rating   votes   duration  \
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
#looking for last 11 values
df.tail(11)
# Out:
#                                          title  year  rating  votes  \
# ID
# tt0101356                   Another You (1991)  1991     4.9   1359
# tt0421090                    Zerophilia (2005)  2005     6.3   1359
# tt0067227  The Merchant of Four Seasons (1971)  1971     7.6   1359
# tt0339727                     Stateside (2004)  2004     5.8   1358
# tt0218581                  Scarlet Diva (2000)  2000     5.2   1358
# tt0118635                        Aprile (1998)  1998     6.7   1358
# tt0807721                       Meduzot (2007)  2007     7.0   1357
# tt0339642                Daltry Calhoun (2005)  2005     5.2   1357
# tt0060880        The Quiller Memorandum (1966)  1966     6.5   1356
# tt0152836                          Taal (1999)  1999     6.5   1356
# tt0279977                The Navigators (2001)  2001     6.9   1356
#
#             duration                      genres
# ID
# tt0101356   98 mins.                Comedy|Crime
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
# title       10000 non-null object
# year        10000 non-null int64
# rating      10000 non-null float64
# votes       10000 non-null int64
# duration    10000 non-null object
# genres      9999 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %% [markdown]
# # Cleaning

# %%
df
# Out:
#                                                        title  year  rating  \
# ID
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0109830                                Forrest Gump (1994)  1994     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980     8.8
# tt0372784                               Batman Begins (2005)  2005     8.3
# ...

# %%
null_row = df[df.isnull().any(axis=1)]

# %%
null_row
# Out:
#                       title  year  rating  votes  duration genres
# ID
# tt0990404  Chop Shop (2007)  2007     7.2   2104  84 mins.    NaN

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                                        title  year  rating  \
# ID
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0109830                                Forrest Gump (1994)  1994     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980     8.8
# tt0372784                               Batman Begins (2005)  2005     8.3
# ...

# %%
#looking for null file
nulll = df[df.isnull().any(axis=1)]

# %%
nulll
# Out:
# Empty DataFrame
# Columns: [title, year, rating, votes, duration, genres]
# Index: []

# %%
#removing the word mins from the duration
df['duration'] = df['duration'].apply(lambda x : int(x.replace("mins.", '')))

# %%
#converting the minutes in to sedonds
df['duration'] = df['duration'] * 60

# %%
df
# Out:
#                                                        title  year  rating  \
# ID
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0109830                                Forrest Gump (1994)  1994     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980     8.8
# tt0372784                               Batman Begins (2005)  2005     8.3
# ...

# %%
#removing year from the title column
df['title'] = df['title'].apply(lambda x : x[:-6])

# %%
df
# Out:
#                                                        title  year  rating  \
# ID
# tt0111161                          The Shawshank Redemption   1994     9.2
# tt0110912                                      Pulp Fiction   1994     9.0
# tt0137523                                        Fight Club   1999     8.8
# tt0133093                                        The Matrix   1999     8.7
# tt1375666                                         Inception   2010     8.9
# tt0109830                                      Forrest Gump   1994     8.7
# tt0169547                                   American Beauty   1999     8.6
# tt0499549                                            Avatar   2009     8.1
# tt0108052                                  Schindler's List   1993     8.9
# tt0080684    Star Wars: Episode V - The Empire Strikes Back   1980     8.8
# tt0372784                                     Batman Begins   2005     8.3
# ...

# %% [markdown]
# # Concatenating

# %%
#reading file with column names
movie_crew_df = pd.read_csv('/Users/rakeshm/downloads/crew_data.tsv.gz', header = 0, delimiter = '\t', usecols=(0,1),
                            names = ['ID', 'director_ids'])

# %%
movie_crew_df
# Out:
#                 ID         director_ids
# 0        tt0000001            nm0005690
# 1        tt0000002            nm0721526
# 2        tt0000003            nm0721526
# 3        tt0000004            nm0721526
# 4        tt0000005            nm0005690
# 5        tt0000006            nm0005690
# 6        tt0000007  nm0005690,nm0374658
# 7        tt0000008            nm0005690
# 8        tt0000009            nm0085156
# 9        tt0000010            nm0525910
# 10       tt0000011            nm0804434
# 11       tt0000012  nm0525908,nm0525910
# 12       tt0000013            nm0525910
# 13       tt0000014            nm0525910
# 14       tt0000015            nm0721526
# 15       tt0000016            nm0525910
# 16       tt0000017  nm0804434,nm1587194
# 17       tt0000018            nm0804434
# 18       tt0000019            nm0932055
# 19       tt0000020            nm0010291
# 20       tt0000022            nm0525910
# 21       tt0000023            nm0525910
# ...

# %%
#movie_crew_df['ID'] = movie_crew_df.index
movie_crew_df.set_index('ID', inplace =True)
movie_crew_df
# Out:
#                   director_ids
# ID
# tt0000001            nm0005690
# tt0000002            nm0721526
# tt0000003            nm0721526
# tt0000004            nm0721526
# tt0000005            nm0005690
# tt0000006            nm0005690
# tt0000007  nm0005690,nm0374658
# tt0000008            nm0005690
# tt0000009            nm0085156
# tt0000010            nm0525910
# tt0000011            nm0804434
# tt0000012  nm0525908,nm0525910
# tt0000013            nm0525910
# tt0000014            nm0525910
# tt0000015            nm0721526
# tt0000016            nm0525910
# tt0000017  nm0804434,nm1587194
# tt0000018            nm0804434
# tt0000019            nm0932055
# tt0000020            nm0010291
# tt0000022            nm0525910
# tt0000023            nm0525910
# tt0000024            nm0010291
# tt0000025            nm0010291
# tt0000026            nm0525910
# tt0000027            nm0525910
# tt0000028            nm0525910
# tt0000029            nm0525910
# tt0000030  nm0666972,nm0010291
# ...

# %%
#uploading another dataset named name_data.tsv.gz
person_df =pd.read_csv('/Users/rakeshm/downloads/name_data.tsv.gz', delimiter = '\t', header=0, 
                       usecols=(0,1), names=['person_ID', 'name'])

# %%
person_df
# Out:
#          person_ID                 name
# 0        nm0000001         Fred Astaire
# 1        nm0000002        Lauren Bacall
# 2        nm0000003      Brigitte Bardot
# 3        nm0000004         John Belushi
# 4        nm0000005       Ingmar Bergman
# 5        nm0000006       Ingrid Bergman
# 6        nm0000007      Humphrey Bogart
# 7        nm0000008        Marlon Brando
# 8        nm0000009       Richard Burton
# 9        nm0000010         James Cagney
# 10       nm0000011          Gary Cooper
# 11       nm0000012          Bette Davis
# 12       nm0000013            Doris Day
# 13       nm0000014  Olivia de Havilland
# 14       nm0000015           James Dean
# 15       nm0000016      Georges Delerue
# 16       nm0000017     Marlene Dietrich
# 17       nm0000018         Kirk Douglas
# 18       nm0000019     Federico Fellini
# 19       nm0000020          Henry Fonda
# 20       nm0000021        Joan Fontaine
# 21       nm0000022          Clark Gable
# ...

# %%
#setting index to person_ID
person_df.set_index('person_ID', inplace =True)

# %%
person_df
# Out:
#                           name
# person_ID
# nm0000001         Fred Astaire
# nm0000002        Lauren Bacall
# nm0000003      Brigitte Bardot
# nm0000004         John Belushi
# nm0000005       Ingmar Bergman
# nm0000006       Ingrid Bergman
# nm0000007      Humphrey Bogart
# nm0000008        Marlon Brando
# nm0000009       Richard Burton
# nm0000010         James Cagney
# nm0000011          Gary Cooper
# nm0000012          Bette Davis
# nm0000013            Doris Day
# nm0000014  Olivia de Havilland
# nm0000015           James Dean
# nm0000016      Georges Delerue
# nm0000017     Marlene Dietrich
# nm0000018         Kirk Douglas
# nm0000019     Federico Fellini
# nm0000020          Henry Fonda
# nm0000021        Joan Fontaine
# nm0000022          Clark Gable
# nm0000023         Judy Garland
# nm0000024         John Gielgud
# nm0000025      Jerry Goldsmith
# nm0000026           Cary Grant
# nm0000027        Alec Guinness
# nm0000028        Rita Hayworth
# ...

# %%
#Merge movie_crew_df into df with IDs and drop the columns
pdd = pd.merge(df, movie_crew_df, on = 'ID', how = 'inner')
pdd.head()
#pdd.dropna(inplace=True)
# Out:
#                                title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt0133093                The Matrix   1999     8.7  448114      8160
# tt1375666                 Inception   2010     8.9  385149      8880
#
#                                      genres         director_ids
# ID
# tt0111161                       Crime|Drama            nm0001104
# tt0110912                    Crime|Thriller            nm0000233
# tt0137523            Drama|Mystery|Thriller            nm0000399
# tt0133093           Action|Adventure|Sci-Fi  nm0905154,nm0905152
# tt1375666  Action|Adventure|Sci-Fi|Thriller            nm0634240

# %%
pdd.isna().sum()
# Out:
# title           0
# year            0
# rating          0
# votes           0
# duration        0
# genres          0
# director_ids    0
# dtype: int64

# %%
#Remove movies with more than one director and rename director_ids => director_id
pdd = pdd.loc[pdd["director_ids"].str.len()==9]

# %%
pdd.head()
# Out:
#                                title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt1375666                 Inception   2010     8.9  385149      8880
# tt0109830              Forrest Gump   1994     8.7  368994      8520
#
#                                      genres director_ids
# ID
# tt0111161                       Crime|Drama    nm0001104
# tt0110912                    Crime|Thriller    nm0000233
# tt0137523            Drama|Mystery|Thriller    nm0000399
# tt1375666  Action|Adventure|Sci-Fi|Thriller    nm0634240
# tt0109830              Comedy|Drama|Romance    nm0000709

# %%
#renaming the column,  director_ids"to "director_id
pdd.rename(columns = {"director_ids":"director_id"}, inplace=True)

# %%
pdd.head()
# Out:
#                                title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt1375666                 Inception   2010     8.9  385149      8880
# tt0109830              Forrest Gump   1994     8.7  368994      8520
#
#                                      genres director_id
# ID
# tt0111161                       Crime|Drama   nm0001104
# tt0110912                    Crime|Thriller   nm0000233
# tt0137523            Drama|Mystery|Thriller   nm0000399
# tt1375666  Action|Adventure|Sci-Fi|Thriller   nm0634240
# tt0109830              Comedy|Drama|Romance   nm0000709

# %%
#Merge df with person_df on director_id, remove director_id and person_ID columns, rename name => director

phd= pd.merge(pdd, person_df, left_on='director_id', right_on='person_ID', how='inner')

# %%
phd.head()
# Out:
#                        title  year  rating   votes  duration  \
# 0  The Shawshank Redemption   1994     9.2  619479      8520
# 1            The Green Mile   1999     8.4  243660     11340
# 2                  The Mist   2007     7.4   90987      7560
# 3              The Majestic   2001     6.8   27241      9120
# 4              Pulp Fiction   1994     9.0  490065      9240
#
#                         genres director_id               name
# 0                  Crime|Drama   nm0001104     Frank Darabont
# 1  Crime|Drama|Fantasy|Mystery   nm0001104     Frank Darabont
# 2       Horror|Sci-Fi|Thriller   nm0001104     Frank Darabont
# 3                Drama|Romance   nm0001104     Frank Darabont
# 4               Crime|Thriller   nm0000233  Quentin Tarantino

# %%
#droping the column called director_id
phd.drop(columns = 'director_id', axis=1, inplace=True)
phd.head()
# Out:
#                        title  year  rating   votes  duration  \
# 0  The Shawshank Redemption   1994     9.2  619479      8520
# 1            The Green Mile   1999     8.4  243660     11340
# 2                  The Mist   2007     7.4   90987      7560
# 3              The Majestic   2001     6.8   27241      9120
# 4              Pulp Fiction   1994     9.0  490065      9240
#
#                         genres               name
# 0                  Crime|Drama     Frank Darabont
# 1  Crime|Drama|Fantasy|Mystery     Frank Darabont
# 2       Horror|Sci-Fi|Thriller     Frank Darabont
# 3                Drama|Romance     Frank Darabont
# 4               Crime|Thriller  Quentin Tarantino

# %%
#renaming the name column to director
phd.rename(columns = {"name":"director"}, inplace=True)

# %%
phd.head()
# Out:
#                        title  year  rating   votes  duration  \
# 0  The Shawshank Redemption   1994     9.2  619479      8520
# 1            The Green Mile   1999     8.4  243660     11340
# 2                  The Mist   2007     7.4   90987      7560
# 3              The Majestic   2001     6.8   27241      9120
# 4              Pulp Fiction   1994     9.0  490065      9240
#
#                         genres           director
# 0                  Crime|Drama     Frank Darabont
# 1  Crime|Drama|Fantasy|Mystery     Frank Darabont
# 2       Horror|Sci-Fi|Thriller     Frank Darabont
# 3                Drama|Romance     Frank Darabont
# 4               Crime|Thriller  Quentin Tarantino

# %% [markdown]
# # Exploration

# %%
# Find ten most longest movies 
# # movies_duration= df['duration']
# # Function returns 10  largest mocies 
# def Nmaxelements(movies_duration, N): 
#     final_list = [] 
  
#     for i in range(0, N):  
#         max1 = 0
  
#         for j in range(len(movies_duration)):      
#             if movies_duration[j] > max1: 
#                 max1 = movies_duration[j]; 
                  
#         movies_duration.remove(max1); 
#         final_list.append(max1) 
          
#     print(final_list) 
# # Driver code 
# movies_duration= df['duration'].tolist()
# N=10
# # Calling the function 
# Nmaxelements(movies_duration, N)

# %%
#finding the 10 longerst movies
phd.nlargest(10,"duration")
# Out:
#                                    title  year  rating  votes  duration  \
# 8059                         Satantango   1994     8.5   2698     27000
# 7958                      War and Peace   1967     7.8   2833     25620
# 5230                         Gettysburg   1993     7.7  12093     15660
# 1941                             Hamlet   1996     7.7  19698     14520
# 6246                      Love Exposure   2008     8.0   1922     14220
# 8131                  La Belle Noiseuse   1991     7.6   2621     14160
# 6126                             Ludwig   1972     7.6   1581     14100
# 341         Once Upon a Time in America   1984     8.4  85533     13740
# 4881  Lagaan: Once Upon a Time in India   2001     8.1  14190     13440
# 3956               The Ten Commandments   1956     7.9  22789     13200
#
#                             genres            director
# 8059          Comedy|Drama|Mystery           Béla Tarr
# 7958     Drama|History|Romance|War   Sergey Bondarchuk
# ...

# %%
#Find Best rated movies ordered by rating DESC and Title ASC

phd.sort_values(by=['rating', 'title'], ascending=[False, True])
# Out:
#                                                   title  year  rating   votes  \
# 145                                      The Godfather   1972     9.2  474189
# 0                             The Shawshank Redemption   1994     9.2  619479
# 5636                                  Outrageous Class   1975     9.0    9823
# 4                                         Pulp Fiction   1994     9.0  490065
# 146                             The Godfather: Part II   1974     9.0  291169
# 339                     The Good, the Bad and the Ugly   1966     9.0  195238
# 631                                       12 Angry Men   1957     8.9  148155
# 18                                           Inception   2010     8.9  385149
# 215                    One Flew Over the Cuckoo's Nest   1975     8.9  255503
# 52                                    Schindler's List   1993     8.9  325888
# 21                                     The Dark Knight   2008     8.9  555122
# ...

# %%
#What is the average duration (in minutes) of a movie?

# import statistics 
# x = statistics.mean((phd['duration'])) 
# x = x/60

# print(f'the average duration of all the movies  : {x} minutes')

# %%
#average duration of movies in minuetes
mea= phd['duration'].mean()
mea= mea/60
mea
# Out:
# 104.05281541066893

# %%
#Get ten most productive directors,  productive director is subjective, 
#it could be about number of films produced or ratings of movies or votes
#We are judging being productive by the votes

phd.nlargest(10, 'votes')
# Out:
#                                                  title  year  rating   votes  \
# 0                            The Shawshank Redemption   1994     9.2  619479
# 21                                    The Dark Knight   2008     8.9  555122
# 4                                        Pulp Fiction   1994     9.0  490065
# 145                                     The Godfather   1972     9.2  474189
# 10                                         Fight Club   1999     8.8  458173
# 164  The Lord of the Rings: The Fellowship of the R...  2001     8.8  451263
# 165     The Lord of the Rings: The Return of the King   2003     8.8  428791
# 18                                          Inception   2010     8.9  385149
# 166             The Lord of the Rings: The Two Towers   2002     8.7  383113
# 25                                       Forrest Gump   1994     8.7  368994
#
#      duration                            genres              director
# ...

# %%
#How many movie has been made in the 2000's?, we have checked in original file named df not on phd 
#as it has been manupulated
df['year'].value_counts()[2000]
# Out:
# 326

# %%
#looking for Akira in director column
phd = phd[phd["director"] == "Akira Kurosawa"]

# %%
phd
# Out:
#                     title  year  rating   votes  duration  \
# 853        Seven Samurai   1954     8.8  111707     12420
# 854             Rashomon   1950     8.4   46250      5280
# 855                  Ran   1985     8.3   39096      9720
# 856              Yojimbo   1961     8.4   33878      6600
# 857                Ikiru   1952     8.3   18948      8580
# 858      Throne of Blood   1957     8.1   13559      6600
# 859  The Hidden Fortress   1958     8.1   12535      8340
# 860            Kagemusha   1980     7.9   12492     10800
# 861              Sanjuro   1962     8.1    9739      5760
# 862          Dersu Uzala   1975     8.2    9180      8640
# 863         High and Low   1963     8.3    8603      8520
# 864            Red Beard   1965     8.1    5747     11100
# 865   The Bad Sleep Well   1960     8.0    3356      9060
# 866   Rhapsody in August   1991     7.2    2830      5880
# 867         Dodes'ka-den   1970     7.6    2371      8400
# ...

# %%
#Get all the movies directed by Akira Kurosawa ordered by year DESC

# phd = df.sort_index()
# n = phd['director'].tolist()
# m= phd['title'].tolist()

# i= 0
# c= 1
# while c < len(n):
#     c = c+ 1
#     i = i +1
#     if n[i] == 'Akira Kurosawa':
#         print(m[i])
# Out:
# Rashomon
# Ran
# Yojimbo
# Ikiru
# Throne of Blood
# The Hidden Fortress
# Kagemusha
# Sanjuro
# Dersu Uzala
# High and Low
# Red Beard
# The Bad Sleep Well
# Rhapsody in August
# Dodes'ka-den
# Madadayo
# The Lower Depths
# The Idiot
# I Live in Fear

# %%
#sorting by year after comparing with director name
phd.sort_values(by=['year'], ascending=False)
# Out:
#                     title  year  rating   votes  duration  \
# 868             Madadayo   1993     7.4    1935      8040
# 866   Rhapsody in August   1991     7.2    2830      5880
# 855                  Ran   1985     8.3   39096      9720
# 860            Kagemusha   1980     7.9   12492     10800
# 862          Dersu Uzala   1975     8.2    9180      8640
# 867         Dodes'ka-den   1970     7.6    2371      8400
# 864            Red Beard   1965     8.1    5747     11100
# 863         High and Low   1963     8.3    8603      8520
# 861              Sanjuro   1962     8.1    9739      5760
# 856              Yojimbo   1961     8.4   33878      6600
# 865   The Bad Sleep Well   1960     8.0    3356      9060
# 859  The Hidden Fortress   1958     8.1   12535      8340
# 869     The Lower Depths   1957     7.5    1901      8220
# 858      Throne of Blood   1957     8.1   13559      6600
# 871       I Live in Fear   1955     7.3    1360      6180
# ...
